# %% [markdown]
# # Insurance

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("C:/Users/ASUS/Downloads/insurance.csv")

# %%
pd.set_option('display.max_rows', None)
data
# Out:
#       age     sex     bmi  children smoker     region       charges
# 0      19  female  27.900         0    yes  southwest  16884.924000
# 1      18    male  33.770         1     no  southeast   1725.552300
# 2      28    male  33.000         3     no  southeast   4449.462000
# 3      33    male  22.705         0     no  northwest  21984.470610
# 4      32    male  28.880         0     no  northwest   3866.855200
# 5      31  female  25.740         0     no  southeast   3756.621600
# 6      46  female  33.440         1     no  southeast   8240.589600
# 7      37  female  27.740         3     no  northwest   7281.505600
# 8      37    male  29.830         2     no  northeast   6406.410700
# 9      60  female  25.840         0     no  northwest  28923.136920
# 10     25    male  26.220         0     no  northeast   2721.320800
# 11     62  female  26.290         0    yes  southeast  27808.725100
# 12     23    male  34.400         0     no  southwest   1826.843000
# ...

# %%
data.iloc[:,1].replace({'female':0,'male':1}, inplace=True)

# %%
#data.iloc[:,4].replace({'yes':1,'no':0}, inplace=True)

# %%
data.iloc[:,5].replace({'southwest':1,'southeast':2,'northwest':3,'northeast':4},inplace=True)

# %% [markdown]
# - southwest 1
# - southeast 2
# - northwest 3
# - northeast 4

# %%
data
# Out:
#       age  sex     bmi  children smoker  region       charges
# 0      19    0  27.900         0    yes       1  16884.924000
# 1      18    1  33.770         1     no       2   1725.552300
# 2      28    1  33.000         3     no       2   4449.462000
# 3      33    1  22.705         0     no       3  21984.470610
# 4      32    1  28.880         0     no       3   3866.855200
# 5      31    0  25.740         0     no       2   3756.621600
# 6      46    0  33.440         1     no       2   8240.589600
# 7      37    0  27.740         3     no       3   7281.505600
# 8      37    1  29.830         2     no       4   6406.410700
# 9      60    0  25.840         0     no       3  28923.136920
# 10     25    1  26.220         0     no       4   2721.320800
# 11     62    0  26.290         0    yes       2  27808.725100
# 12     23    1  34.400         0     no       1   1826.843000
# 13     56    0  39.820         0     no       2  11090.717800
# ...

# %%
sns.boxplot(x='age', data=data)
plt.xlabel('Age x variable')
plt.show()

# %%
sns.boxplot(x='sex', data=data)
plt.xlabel('sex as x variable')
plt.show()

# %%
sns.boxplot(x='bmi', data=data)
plt.xlabel('bmi as variable')
plt.show()

# %%
data.bmi.mean()
# Out:
# 30.66339686098655

# %%
data1 = data[data.iloc[:,2]<45]
data1
# Out:
#       age  sex     bmi  children smoker  region       charges
# 0      19    0  27.900         0    yes       1  16884.924000
# 1      18    1  33.770         1     no       2   1725.552300
# 2      28    1  33.000         3     no       2   4449.462000
# 3      33    1  22.705         0     no       3  21984.470610
# 4      32    1  28.880         0     no       3   3866.855200
# 5      31    0  25.740         0     no       2   3756.621600
# 6      46    0  33.440         1     no       2   8240.589600
# 7      37    0  27.740         3     no       3   7281.505600
# 8      37    1  29.830         2     no       4   6406.410700
# 9      60    0  25.840         0     no       3  28923.136920
# 10     25    1  26.220         0     no       4   2721.320800
# 11     62    0  26.290         0    yes       2  27808.725100
# 12     23    1  34.400         0     no       1   1826.843000
# 13     56    0  39.820         0     no       2  11090.717800
# ...

# %%
sns.displot(data['charges'], kde=True, aspect=3, height=6)
plt.title('Charges Plot', loc='center', fontsize=30)
# Out:
# C:\Users\ASUS\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# Text(0.5, 1.0, 'Charges Plot')

# %%
charges = data['charges'].groupby(data.region).sum().sort_values(ascending=True)
f, ax = plt.subplots(figsize=(8, 6))
sns.barplot(x=charges.head(), y=charges.head().index, palette='Blues', ax=ax)
plt.xlabel('Charges')
plt.ylabel('Region')
plt.title('Total Charges by Region')
plt.show()

# %%
f, ax = plt.subplots(1, 1, figsize=(12, 8))
ax = sns.barplot(x='region', y='charges', hue='sex', data=data, palette='cool')
plt.show()

# %%
f, ax=plt.subplots(1,1, figsize=(12,8))
ax = sns.barplot(x='region', y='charges', hue='smoker', data=data, palette='Reds_r')
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Create a figure with 1 row and 3 columns for the subplots
fig, axes = plt.subplots(1, 3, figsize=(18, 6))

# Plotting age vs charges with smoker distinction
sns.lmplot(x='age', y='charges', data=data, hue='smoker', palette='Set1')
axes[0].set_title('Age vs Charges')

# Plotting bmi vs charges with smoker distinction
sns.lmplot(x='bmi', y='charges', data=data, hue='smoker', palette='Set2')
axes[1].set_title('BMI vs Charges')

# Plotting children vs charges with smoker distinction
sns.lmplot(x='children', y='charges', data=data, hue='smoker', palette='Set3')
axes[2].set_title('Children vs Charges')

# Remove overlapping titles
plt.tight_layout()

# Show the plots
plt.show()

# %%
plt.subplots(1,1, figsize=[12,8])
sns.barplot(x='region', y='charges', hue='children', data=data, palette='Set1')
plt.show()

# %%
# Assuming 'data' is your DataFrame
data['children'] = data['children'].astype('category')

# Create the plo
plt.figure(figsize=[12, 8])
sns.barplot(x='region', y='charges', hue='children', data=data, palette='Set1')

# Add legend
plt.legend(title='Children', loc='upper right')

# Show the plot
plt.show()

# %%
sns.violinplot(x = 'children', y = 'charges', data=data,
                 orient='v', hue='smoker', palette='inferno')
plt.show()
# Out:
# C:\Users\ASUS\anaconda3\Lib\site-packages\seaborn\categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)
# C:\Users\ASUS\anaconda3\Lib\site-packages\seaborn\categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)

# %% [markdown]
# # Encoding and Data Processing.

# %%
data[['sex', 'smoker', 'region']] = data[['sex', 'smoker', 'region']].astype('category')
data.dtypes
# Out:
# age            int64
# sex         category
# bmi          float64
# children    category
# smoker      category
# region      category
# charges      float64
# dtype: object

# %%
from sklearn.preprocessing import LabelEncoder

# Sample categorical data
categories = ['cat', 'dog', 'bird', 'cat', 'bird']

# Create a LabelEncoder object
label_encoder = LabelEncoder()

# Fit the encoder and transform the categories into numerical labels
encoded_labels = label_encoder.fit_transform(categories)

# Display the original categories and their corresponding numerical labels
print("Original Categories:", categories)
print("Encoded Labels:", encoded_labels)

# Reverse the transformation to get back the original categories
decoded_categories = label_encoder.inverse_transform(encoded_labels)
print("Decoded Categories:", decoded_categories)
# Out:
# Original Categories: ['cat', 'dog', 'bird', 'cat', 'bird']
# Encoded Labels: [1 2 0 1 0]
# Decoded Categories: ['cat' 'dog' 'bird' 'cat' 'bird']

# %%
##Converting category labels into numerical using LabelEncoder
from sklearn.preprocessing import LabelEncoder
label = LabelEncoder()
label.fit(data.sex.drop_duplicates())
Encoded_labels = data.sex = label.transform(data.sex)
label.fit(data.smoker.drop_duplicates())
Encoded_labels_2 = data.smoker = label.transform(data.smoker)
label.fit(data.region.drop_duplicates())
Encoded_labels_3 = data.region = label.transform(data.region)
print('Encoded_labels', Encoded_labels)
print('Encoded_labels_2', Encoded_labels)
print('Encoded_labels_3', Encoded_labels)
data.dtypes
# Out:
# Encoded_labels [0 1 1 ... 0 0 0]
# Encoded_labels_2 [0 1 1 ... 0 0 0]
# Encoded_labels_3 [0 1 1 ... 0 0 0]
# age            int64
# sex            int64
# bmi          float64
# children    category
# smoker         int32
# region         int64
# charges      float64
# dtype: object

# %%
data
# Out:
#       age  sex     bmi children  smoker  region       charges
# 0      19    0  27.900        0       1       0  16884.924000
# 1      18    1  33.770        1       0       1   1725.552300
# 2      28    1  33.000        3       0       1   4449.462000
# 3      33    1  22.705        0       0       2  21984.470610
# 4      32    1  28.880        0       0       2   3866.855200
# 5      31    0  25.740        0       0       1   3756.621600
# 6      46    0  33.440        1       0       1   8240.589600
# 7      37    0  27.740        3       0       2   7281.505600
# 8      37    1  29.830        2       0       3   6406.410700
# 9      60    0  25.840        0       0       2  28923.136920
# 10     25    1  26.220        0       0       3   2721.320800
# 11     62    0  26.290        0       1       1  27808.725100
# 12     23    1  34.400        0       0       0   1826.843000
# 13     56    0  39.820        0       0       1  11090.717800
# ...

# %% [markdown]
# # Correlation & Heatmap

# %%
 plt.subplots(1, 1, figsize=(10, 10))
sns.heatmap(data.corr(), annot=True, cmap='cool', annot_kws={"size": 15})
plt.show()

# %% [markdown]
# #  Model Creation

# %% [markdown]
# ## Linear Regression

# %%
from sklearn.model_selection import train_test_split as holdout
from sklearn.linear_model import LinearRegression
from sklearn import metrics
x = data.drop(['charges'], axis = 1)
y = data['charges']
x_train, x_test, y_train, y_test = holdout(x, y, test_size=0.2, random_state=0)
Lin_reg = LinearRegression()
Lin_reg.fit(x_train, y_train)
print("Linear_regression_Intercept:", Lin_reg.intercept_)
print("Lin_reg.coef:", Lin_reg.coef_)
print("Lin_reg.score:", Lin_reg.score(x_test, y_test))
# Out:
# Linear_regression_Intercept: -12527.50962645557
# Lin_reg.coef: [  253.99185244   -24.32455098   328.40261701   443.72929547
#  23568.87948381   288.50857254]
# Lin_reg.score: 0.7998747145449959

# %% [markdown]
# ## Lasso Regression

# %%
from sklearn.linear_model import Lasso
Lasso = Lasso(alpha=0.2, fit_intercept=True, precompute=False, max_iter=1000,
              tol=0.0001, warm_start=False, positive=False, random_state=None, selection='cyclic')
Lasso.fit(x_train, y_train)
print("Lasso.intercept_:", Lasso.intercept_)
print("Lasso.coef:_", Lasso.coef_)
print("Lasso.score:", Lasso.score(x_test, y_test))
# Out:
# Lasso.intercept_: -12526.859816338152
# Lasso.coef:_ [ 2.53991436e+02 -2.34569821e+01  3.28389438e+02  4.43587436e+02
#   2.35676136e+04  2.88340296e+02]
# Lasso.score: 0.7998690236224705

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn import metrics
from sklearn.model_selection import train_test_split

# Assuming you have a DataFrame called 'df' with features and target variable
x = data.drop(['charges'], axis=1)
y = data.charges

# Split the data into training and testing sets
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=1)

# Create a RandomForestRegressor with specified parameters
Rfr = RandomForestRegressor(n_estimators=100, criterion='squared_error', random_state=1, n_jobs=-1)

# Train the model on the training data
Rfr.fit(x_train, y_train)

# Make predictions on the training and test sets
x_train_pred = Rfr.predict(x_train)
x_test_pred = Rfr.predict(x_test)

# Evaluate the model's performance using Mean Squared Error (MSE) and R-squared (R2)
print('MSE train data: %.3f, MSE test data: %.3f' % 
      (metrics.mean_squared_error(y_train, x_train_pred),
       metrics.mean_squared_error(y_test, x_test_pred)))

print('R2 train data: %.3f, R2 test data: %.3f' % 
      (metrics.r2_score(y_train, x_train_pred),
       metrics.r2_score(y_test, x_test_pred)))
# Out:
# MSE train data: 3489769.152, MSE test data: 21672775.604
# R2 train data: 0.976, R2 test data: 0.855

# %%
plt.figure(figsize=(8,6))

plt.scatter(x_train_pred, x_train_pred - y_train,
          c = 'gray', marker = 'o', s = 35, alpha = 0.5,
          label = 'Train data')
plt.scatter(x_test_pred, x_test_pred - y_test,
          c = 'blue', marker = 'o', s = 35, alpha = 0.7,
          label = 'Test data')
plt.xlabel('Predicted values')
plt.ylabel('Actual values')
plt.legend(loc = 'upper right')
plt.hlines(y = 0, xmin = 0, xmax = 60000, lw = 2, color = 'red')

# %%
print('Feature importance ranking\n\n')
importances = Rfr.feature_importances_
std = np.std([tree.feature_importances_ for tree in Rfr.estimators_],axis=0)
indices = np.argsort(importances)[::-1]
variables = ['age', 'sex', 'bmi', 'children','smoker', 'region']
importance_list = []
for f in range(x.shape[1]):
    variable = variables[indices[f]]
    importance_list.append(variable)
    print("%d.%s(%f)" % (f + 1, variable, importances[indices[f]]))

# Plot the feature importances of the forest
plt.figure()
plt.title("Feature importances")
plt.bar(importance_list, importances[indices],
       color="y", yerr=std[indices], align="center")
# Out:
# Feature importance ranking
#
#
# 1.smoker(0.617874)
# 2.bmi(0.210058)
# 3.age(0.131523)
# 4.children(0.018995)
# 5.region(0.014800)
# 6.sex(0.006750)
# <BarContainer object of 6 artists>

# %% [markdown]
# # Result
# ## Conclusion: like we previously noticed smoking is the greatest factor that affects medical cost charges, then it's bmi and age. Polynomial Regression turned out to be the best model
